# %% [markdown]
# ## 🏨 Problem Statement: Hotel Booking Cancellations
#
# In recent years, **City Hotel** and **Resort Hotel** have experienced high cancellation rates. As a result, each hotel is currently facing several operational challenges, including:
# * 📉 **Fewer revenues**
# * 🏨 **Less than ideal hotel room utilization**
#
# Consequently, **lowering cancellation rates** is the primary goal for both hotels to increase revenue efficiency. The objective of this report is to provide thorough business advice to address this ongoing problem.
#
# ---
#
# ### 📊 Scope of the Report
# The main topics of this report focus on:
# 1. The analysis of hotel booking cancellations.
# 2. Other underlying factors that influence their business operations and yearly revenue generation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("./hotel_booking.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.loc[0:4,"adults":"customer_type"]
# Out:
#    adults  children  babies meal country market_segment distribution_channel  \
# 0       2       0.0       0   BB     PRT         Direct               Direct
# 1       2       0.0       0   BB     PRT         Direct               Direct
# 2       1       0.0       0   BB     GBR         Direct               Direct
# 3       1       0.0       0   BB     GBR      Corporate            Corporate
# 4       2       0.0       0   BB     GBR      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])
df['reservation_status_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print("-"*70)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# #### Data Cleaning :

# %%
df.drop(['company','agent'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# #### Removing Extreme System Anomalies & Logical Errors:

# %%
# Personal information is not required for our analysis
df.drop(columns=['name', 'email', 'phone-number', 'credit_card'], inplace=True) # axis = 1 without passing the list in columns parameter

# %%
df_cleaned = df[(df['adr'] > 0) & (df['adr'] < 5000)]

# there will be no booking if the adults count 0 that's shows a logical error
df_cleaned = df_cleaned[df_cleaned['adults'] > 0]

# adults,children,babies,adr
# for col in df.describe().columns:
#     plt.figure(figsize=(6,4))
#     sns.boxplot(df[col])
#     plt.title(col)
#     plt.show()

# %%
# Now a days any parent's does not have that much children and babies that max to max 3 in reality;
#  Let's assume that may be representing a group i don't want to count groups as a single txn
df_cleaned = df_cleaned[df_cleaned['children'] < 10]
df_cleaned = df_cleaned[df_cleaned['babies'] < 9]
df_cleaned[['adults', 'children', 'babies']].max()
# Out:
# adults      4.0
# children    3.0
# babies      2.0
# dtype: float64

# %%
df = df_cleaned
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  116707.000000  116707.000000      116707.000000
# mean        0.375864     105.346929        2016.161310
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      19.000000        2016.000000
# 50%         0.000000      71.000000        2016.000000
# 75%         1.000000     162.000000        2017.000000
# max         1.000000     709.000000        2017.000000
# std         0.484347     106.967311           0.706805
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             116707.000000              116707.000000
# mean                  27.138783                  15.803345
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# ### Let's Validate The Statement : "Booking Cancellation Is High" :

# %%
canceled_perc = df['is_canceled'].value_counts(normalize=True)
print(f"{canceled_perc[0]*100:.2f}% of booking is not canceled. \n{canceled_perc[1]*100:.2f}% of booking is cancelled.")

plt.figure(figsize=(5,4))
plt.title("Resevation Status Count")
plt.bar(['Not Canceled', 'Canceled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
plt.ylabel("Number Of Reservations")
plt.show()
# Out:
# 62.41% of booking is not canceled.
# 37.59% of booking is cancelled.

# %%
plt.figure(figsize=(8,4))
ax1 = sns.countplot(x='hotel',hue='is_canceled',data = df,palette='Blues')
ax1.legend(bbox_to_anchor=(1,1))
plt.title("Reservation Count In Both Hotels")
plt.xlabel("Hotels")
plt.ylabel("No. Of Reservations")
plt.legend(["Not Canceled","Canceled"])
plt.show()

# %%
resort_hotel = df[ df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.717051
# 1    0.282949
# Name: proportion, dtype: float64

# %%
city_hotel = df[df["hotel"]=="City Hotel"]
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.577763
# 1    0.422237
# Name: proportion, dtype: float64

# %% [markdown]
# ### 🏷️ Key Financial Metric: Average Daily Rate (ADR)
#
# **Average Daily Rate (ADR)** is a core Hospitality Business Intelligence KPI used to calculate the average realized revenue generated per occupied room per day. It serves as the baseline for tracking dynamic pricing performance and pricing sensitivity.
#
# #### **Formula:**
#
# $$\text{ADR} = \frac{\text{Total Room Revenue}}{\text{Number of Rooms Sold}}$$
#
# #### **Operational Constraints in This Dataset:**
# * **Included:** Only rooms that were physically occupied and generated active revenue.
# * **Excluded:** Complimentary rooms ($\text{ADR} = 0$), cancelled bookings where no fee was collected, and structural data entry anomalies (e.g., $\text{ADR} < 0$).

# %%
resort_avg_adr = resort_hotel.groupby('reservation_status_date')[["adr"]].mean()
city_avg_adr = city_hotel.groupby('reservation_status_date')[["adr"]].mean()

# %%
plt.figure(figsize=(15,6))
plt.title("Monthly Average Daily Rate Trends (2015-2017)", fontsize=14, fontweight='bold')
plt.plot(resort_avg_adr.index,resort_avg_adr.values,label="Resort Hotel")
plt.plot(city_avg_adr.index,city_avg_adr.values,label="City Hotel")
plt.xlabel("Year-Month",fontsize=12)
plt.ylabel("Average Daily Rate",fontsize=12)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# ### 📈 Key Insights & Trends: Average Daily Rate (ADR) Analysis
#
# * **Extreme Resort Seasonality:** **Resort Hotels** (blue line) exhibit high price volatility driven by seasons. Room rates skyrocket to massive peaks every summer (July–August) and plunge to their lowest depths every winter (January).
# * **Stable City Hotel Pricing:** **City Hotels** (orange line) maintain a much more stable and predictable pricing structure throughout the year, avoiding the dramatic seasonal swings seen in resorts.
# * **Seasonal Price Inversions:**
#   * *In the Summer:* Resort Hotels become significantly more expensive than City Hotels, peaking near \$250.
#   * *In the Winter:* The trend flips entirely, and City Hotels become the more expensive option as resort demand bottoms out.
# * **Year-over-Year Growth:** Both property types show a steady, upward baseline trend from 2015 through 2017, indicating overall market growth, increased demand, or inflation over time.
# * **Data Anomaly (Late 2014):** The perfectly flat, overlapping lines at the very beginning of the timeline strongly indicate missing or placeholder data prior to active tracking in early 2015.

# %%
df["month"] = df["reservation_status_date"].dt.month

plt.figure(figsize=(15,7.5))
plt.title("Reservation Status Per Month",fontsize=14,fontweight="bold")
sns.countplot(x="month" , hue="is_canceled", data=df)
plt.xlabel("Month",fontsize=12)
plt.ylabel("Reservation Status Count",fontsize=12)
plt.legend(["Not Canceled","Canceled"])
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title("ADR Per Month For Canceled Reservations",fontsize=18)
sns.barplot(x='month',y='adr',data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.xlabel("Month",fontsize=16)
plt.ylabel("ADR",fontsize=16)
plt.show()

# %% [markdown]
# ### 📉 Insights & Trends: Monthly ADR for Canceled Reservations
#
# * **Peak Revenue Loss in January:** Month 1 (January) shows the highest Average Daily Rate (ADR) for canceled bookings, soaring well over 500,000. This suggests high-value bookings made for the start of the year are highly prone to cancellations.
# * **Mid-Year Cancellation Spike:** There is a distinct, sharp surge in canceled ADR during Month 7 (July), approaching nearly 500,000. This directly correlates with peak summer travel seasons when room rates and booking volumes are typically at their highest.
# * **Steady First-Quarter Decline:** Following the January peak, the ADR of canceled bookings steadily decreases through February, March, and April, holding relatively flat before dropping further into May and June.
# * **Lowest Cancellation Impact in September:** Month 9 (September) registers the lowest canceled ADR on the chart, dropping below 300,000. This marks the period where cancellations hit their yearly bottom.
# * **Stable Late-Year Trend:** From Month 8 through Month 12 (August to December), the canceled ADR stabilizes, fluctuating consistently between 250,000 and 330,000 without any major spikes.

# %%
canceled_data = df[df["is_canceled"]==1]
top_10_country = canceled_data['country'].value_counts()[0:10] # value_counts(ascending=False)

plt.figure(figsize=(6,6))
plt.title("Geographic Breakdown of Canceled Hotel Bookings (Top 10)")
plt.pie(top_10_country,autopct="%.2f",labels=top_10_country.index)
plt.show()

# %% [markdown]
# ### 🌍 Geographic Breakdown of Canceled Hotel Bookings (Top 10)
#
# * **Massive Dominance by PRT:** **Portugal (PRT)** accounts for a staggering **70.00%** of all cancellations among the top 10 countries. This overwhelming majority suggests the dataset is heavily concentrated around hotels located within Portugal or primarily catering to Portuguese travelers.
# * **Secondary Market Impact (GBR & ESP):** **Great Britain (GBR)** and **Spain (ESP)** represent the next largest shares of cancellations at **6.27%** and **5.57%** respectively. Together with Portugal, these three European nations make up over 80% of the entire pie chart.
# * **Core Western European Presence:** Neighboring European countries follow closely behind with **France (FRA)** at **4.94%**, **Italy (ITA)** at **3.40%**, and **Germany (DEU)** at **3.11%**.
# * **Minor Global Footprint:** The remaining countries—**Ireland (IRL)** at 2.13%, **Brazil (BRA)** at 2.11%, the **United States (USA)** at 1.27%, and **Belgium (BEL)** at 1.20%—contribute minimally to the overall cancellation volume.
# * **Actionable Takeaway:** Any cancellation prevention strategy, booking policy changes, or marketing adjustments should be heavily customized to target the Portuguese market, as it drives the vast majority of lost booking volume.

# %% [markdown]
# ### Let's Assume that the most of reservations are coming from Offline travel agents

# %%
market_segment_data = df.groupby('is_canceled')["market_segment"].value_counts(normalize = True).reset_index(name='proportion')

plt.figure(figsize=(8,6))
sns.barplot(data=market_segment_data, x='market_segment', y='proportion', hue='is_canceled', palette='muted')
plt.title("Proportion of Market Segments by Reservation Status", fontsize=14, fontweight='bold')
plt.xlabel("Market Segment", fontsize=12)
plt.ylabel("Proportion (Percentage)", fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Reservation Status", labels=["Not Canceled", "Canceled"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🕵️‍♂️ Key Insights & Assumption Verification
#
# * **Assumption Disproven:** The data shows that the initial assumption is incorrect. **Online TA (Online Travel Agents)** is the dominant market segment for both kept and canceled bookings, not Offline TA.
# * **Dominance of Online Bookings (Kept):** For completed stays (`is_canceled = 0`), **Online TA** accounts for the largest share at **48.30%**, which is more than double the share of **Offline TA/TO** at **21.40%**.
# * **High-Risk Segment (Groups):** For canceled bookings (`is_canceled = 1`), **Groups** jump significantly to **27.52%** compared to just 10.27% in the kept category. This indicates group bookings have a disproportionately higher risk of canceling.
# * **Online Booking Cancellations:** **Online TA** also leads canceled reservations at **47.06%**, meaning nearly half of all cancellations originate from online platforms.
# * **Most Reliable Segment (Direct):** **Direct** bookings drop from **14.13%** of successful stays down to just **4.29%** of cancellations, proving that customers who book directly with the hotel are highly likely to keep their reservations.

# %%
canceled_data_adr = df[df['is_canceled']==1].groupby('reservation_status_date')[['adr']].mean().sort_values('reservation_status_date')
not_canceled_data_adr = df[df['is_canceled']==0].groupby('reservation_status_date')[['adr']].mean().sort_values('reservation_status_date')

plt.figure(figsize=(10,6))
plt.title("Average Daily Rate : Date wise trends")
plt.plot(not_canceled_data_adr.index,not_canceled_data_adr.values,label="Not Canceled")
plt.plot(canceled_data_adr.index,canceled_data_adr.values,label="Canceled")
plt.xlabel("Year-Month")
plt.ylabel("Average ADR")
plt.legend()
plt.tight_layout()
plt.show()

# %%
canceled_data_adr_2016 = canceled_data_adr.loc[canceled_data_adr.index >= '2016-01-01']
not_canceled_data_adr_2016 = not_canceled_data_adr.loc[not_canceled_data_adr.index >= '2016-01-01']
plt.figure(figsize=(10,6))
plt.title("Average Daily Rate : Date wise trends")
plt.plot(not_canceled_data_adr_2016.index,not_canceled_data_adr_2016.values,label="Not Canceled")
plt.plot(canceled_data_adr_2016.index,canceled_data_adr_2016.values,label="Canceled")
plt.xlabel("Year-Month")
plt.ylabel("Average ADR")
plt.legend()
plt.tight_layout()
plt.show()
